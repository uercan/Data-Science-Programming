# %%
import numpy as np
import random
 
class dataset:  #we declare the parent class which will receive a filename as an argument
    def __init__(self, filename): #with this init we will not only initialize the dataset, but will get an overview of it and some calculations
        self.f = open(filename)
        self.workingdata = [] #we create two empty lists, one for storing all the data from the dataset and other for storing the ten rows that we will work with
        self.aux = []
        for line in self.f.readlines(): #we read the file in the aux list and we put the header in a separate list
            self.val = line.split(",")
            self.aux.append(self.val)
        self.listheader = self.aux[0].copy()
        self.listheader[-1] = self.listheader[-1].rstrip()
        del self.aux[0]
        print("printing the dataset: ",filename, "\n\n", self.listheader)
        for i in range(0,10): #here we put ten random rows in the working data 
            self.workingdata.append(self.aux[random.randint(0,len(self.aux))])
            print(self.workingdata[i])
        for i in range(len(self.workingdata[0])): #after we have printed the dataset, for the numeric values we print mean, standard deviation, variation, and max and min values
            if self.is_number(self.workingdata[0][i]):
                for j in range(10):
                    self.workingdata[j][i] = float(self.workingdata[j][i])
                print("the mean of the row:", self.listheader[i], "is:", self.mean(self.listheader[i]))
                print("the standard deviation of the row:", self.listheader[i], "is:", self.std(self.listheader[i]))
                print("the variation of the row:", self.listheader[i], "is:", self.var(self.listheader[i]))
                print("the maximum value of the row:", self.listheader[i], "is:", self.max(self.listheader[i]))
                print("the minimum value of the row:", self.listheader[i], "is:", self.min(self.listheader[i]))
                print("\n")

    def is_number(self, s): #helper method to check if an element of the list is a numeric value
        try:
            float(s)
            return True
        except ValueError:
            return False

    def mean(self, row): #helper function to calculate mean
        self.index = self.listheader.index(row)
        if isinstance(self.workingdata[0][self.index], float):
            self.auxarray = []
            for i in range(0, 10):
                self.auxarray.append(self.workingdata[i][self.index])
            return np.mean(self.auxarray)
            self.auxarray.clear()
        else:
            print("not a numeric value")

    def std(self, row): #helper function to calculate standard deviation
        self.index = self.listheader.index(row)
        if isinstance(self.workingdata[0][self.index], float):
            self.auxarray = []
            for i in range(0, 10):
                self.auxarray.append(self.workingdata[i][self.index])
            return np.std(self.auxarray)
            self.auxarray.clear()
        else:
            print("not a numeric value")

    def var(self, row): #helper function to calculate variation
        self.index = self.listheader.index(row)
        if isinstance(self.workingdata[0][self.index], float):
            self.auxarray = []
            for i in range(0, 10):
                self.auxarray.append(self.workingdata[i][self.index])
            return np.var(self.auxarray)
            self.auxarray.clear()
        else:
            print("not a numeric value")
    def max(self, row): #helper function to calculate max value
        self.index = self.listheader.index(row)
        if isinstance(self.workingdata[0][self.index], float):
            self.auxarray = []
            for i in range(0, 10):
                self.auxarray.append(self.workingdata[i][self.index])
            return np.max(self.auxarray)
            self.auxarray.clear()
        else:
            print("not a numeric value")

    def min(self, row): #helper function to calculate min value
        self.index = self.listheader.index(row)
        if isinstance(self.workingdata[0][self.index], float):
            self.auxarray = []
            for i in range(0, 10):
                self.auxarray.append(self.workingdata[i][self.index])
            return np.min(self.auxarray)
            self.auxarray.clear()
        else:
            print("not a numeric value")

            
#we declare 2 child classes here using inheritance, one for the covid dataset, and the other for the happiness dataset
class covid(dataset): 
    def __init__(self):
        dataset.__init__(self, 'WHO-COVID-19-global-data.csv')


class happiness(dataset):
    def __init__(self):
        dataset.__init__(self, '2019.csv')

#we call 2 instances of the child classes
happyclass = happiness()
covidicos = covid()
# Out:
# printing the dataset:  2019.csv
#
#  ['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']
# ['133', 'Ukraine', '4.332', '0.820', '1.390', '0.739', '0.178', '0.187', '0.010\n']
# ['127', 'Congo (Kinshasa)', '4.418', '0.094', '1.125', '0.357', '0.269', '0.212', '0.053\n']
# ['1', 'Finland', '7.769', '1.340', '1.587', '0.986', '0.596', '0.153', '0.393\n']
# ['93', 'China', '5.191', '1.029', '1.125', '0.893', '0.521', '0.058', '0.100\n']
# ['104', 'Gabon', '4.799', '1.057', '1.183', '0.571', '0.295', '0.043', '0.055\n']
# ['63', 'Paraguay', '5.743', '0.855', '1.475', '0.777', '0.514', '0.184', '0.080\n']
# ['128', 'Mali', '4.390', '0.385', '1.105', '0.308', '0.327', '0.153', '0.052\n']
# ['135', 'Swaziland', '4.212', '0.811', '1.149', '0.000', '0.313', '0.074', '0.135\n']
# ['27', 'Guatemala', '6.436', '0.800', '1.269', '0.746', '0.535', '0.175', '0.078\n']
# ['53', 'Latvia', '5.940', '1.187', '1.465', '0.812', '0.264', '0.075', '0.064\n']
# the mean of the row: Overall rank is: 86.4
# the standard deviation of the row: Overall rank is: 45.55260695064553
# the variation of the row: Overall rank is: 2075.04
# the maximum value of the row: Overall rank is: 135.0
# the minimum value of the row: Overall rank is: 1.0
#
#
# the mean of the row: Score is: 5.3229999999999995
# the standard deviation of the row: Score is: 1.0943806467587043
# the variation of the row: Score is: 1.197669
# the maximum value of the row: Score is: 7.769
# the minimum value of the row: Score is: 4.212
#
#
# the mean of the row: GDP per capita is: 0.8378
# the standard deviation of the row: GDP per capita is: 0.34925314601303165
# the variation of the row: GDP per capita is: 0.12197776
# the maximum value of the row: GDP per capita is: 1.34
# the minimum value of the row: GDP per capita is: 0.094
#
#
# the mean of the row: Social support is: 1.2872999999999999
# the standard deviation of the row: Social support is: 0.16835441782145188
# the variation of the row: Social support is: 0.02834321
# the maximum value of the row: Social support is: 1.587
# the minimum value of the row: Social support is: 1.105
#
#
# the mean of the row: Healthy life expectancy is: 0.6189000000000001
# the standard deviation of the row: Healthy life expectancy is: 0.2921193078178846
# the variation of the row: Healthy life expectancy is: 0.08533369000000002
# the maximum value of the row: Healthy life expectancy is: 0.986
# the minimum value of the row: Healthy life expectancy is: 0.0
#
#
# the mean of the row: Freedom to make life choices is: 0.38120000000000004
# the standard deviation of the row: Freedom to make life choices is: 0.13769807551305865
# the variation of the row: Freedom to make life choices is: 0.01896076
# the maximum value of the row: Freedom to make life choices is: 0.596
# the minimum value of the row: Freedom to make life choices is: 0.178
#
#
# the mean of the row: Generosity is: 0.13140000000000002
# the standard deviation of the row: Generosity is: 0.05904777726553304
# the variation of the row: Generosity is: 0.0034866400000000005
# the maximum value of the row: Generosity is: 0.212
# the minimum value of the row: Generosity is: 0.043
#
#
# the mean of the row: Perceptions of corruption is: 0.10200000000000001
# the standard deviation of the row: Perceptions of corruption is: 0.10190780146779736
# the variation of the row: Perceptions of corruption is: 0.010385200000000002
# the maximum value of the row: Perceptions of corruption is: 0.393
# the minimum value of the row: Perceptions of corruption is: 0.01
#
#
# printing the dataset:  WHO-COVID-19-global-data.csv
#
#  ['ï»¿Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases', 'Cumulative_cases', 'New_deaths', 'Cumulative_deaths']
# ['2023-01-21', 'PA', 'Panama', 'AMRO', '0', '1028272', '0', '8589\n']
# ['2020-04-30', 'MZ', 'Mozambique', 'AFRO', '0', '76', '0', '0\n']
# ['2021-10-21', 'ZA', 'South Africa', 'AFRO', '591', '2917846', '80', '88754\n']
# ['2023-01-03', 'BO', 'Bolivia (Plurinational State of)', 'AMRO', '583', '1163105', '1', '22305\n']
# ['2022-02-26', 'CM', 'Cameroon', 'AFRO', '0', '119240', '0', '1923\n']
# ['2022-03-10', 'VN', 'Viet Nam', 'WPRO', '265163', '5042036', '109', '41086\n']
# ['2022-11-06', 'SO', 'Somalia', 'EMRO', '0', '27243', '0', '1361\n']
# ['2020-11-03', 'GY', 'Guyana', 'AMRO', '46', '4208', '2', '126\n']
# ['2022-10-03', 'PH', 'Philippines', 'WPRO', '2022', '3953791', '97', '63013\n']
# ['2020-10-08', 'DE', 'Germany', 'EURO', '4498', '313709', '34', '10038\n']
# the mean of the row: New_cases is: 27290.3
# the standard deviation of the row: New_cases is: 79302.47385933179
# the variation of the row: New_cases is: 6288882360.210001
# the maximum value of the row: New_cases is: 265163.0
# the minimum value of the row: New_cases is: 0.0
#
#
# the mean of the row: Cumulative_cases is: 1456952.6
# the standard deviation of the row: Cumulative_cases is: 1756839.6268756122
# the variation of the row: Cumulative_cases is: 3086485474560.4404
# the maximum value of the row: Cumulative_cases is: 5042036.0
# the minimum value of the row: Cumulative_cases is: 76.0
#
#
# the mean of the row: New_deaths is: 32.3
# the standard deviation of the row: New_deaths is: 42.91631391440789
# the variation of the row: New_deaths is: 1841.81
# the maximum value of the row: New_deaths is: 109.0
# the minimum value of the row: New_deaths is: 0.0
#
#
# the mean of the row: Cumulative_deaths is: 23719.5
# the standard deviation of the row: Cumulative_deaths is: 29304.325268635686
# the variation of the row: Cumulative_deaths is: 858743479.45
# the maximum value of the row: Cumulative_deaths is: 88754.0
# the minimum value of the row: Cumulative_deaths is: 0.0
